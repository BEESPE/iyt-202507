# %% [markdown]
# Charger les 2 fichiers CSV inventaires dans des dataframes pandas.

# %%
from pathlib import Path

import pandas as pd
import matplotlib.pyplot as plt

# %%
DATA_DIR = Path("../data")
INPUT_DIR = Path(DATA_DIR, "portfolio-inventories")
OUTPUT_DIR = Path(DATA_DIR, "output")

# %%
PORTFOLIO_CODE = "Portoflio Code"
ASSET_CODE = "Asset Code"
QUANTITY = "Quantity"

# %%
portfolio_1_df = pd.read_csv(
    Path(INPUT_DIR, "day1.ptf_inventories.csv"),
    sep=";"
)

portfolio_2_df = pd.read_csv(
    Path(INPUT_DIR, "day2.ptf_inventories.csv"),
    sep=";"
)

# %% [markdown]
# Explorer ces fichiers pour essayer d'en comprendre la structure.

# %%
portfolio_1_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1148 entries, 0 to 1147
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Portoflio Code          1148 non-null   int64
#  1   Porfoltio Name          1148 non-null   object
#  2   Porfolio Currency       1148 non-null   object
#  3   Holding Date            1148 non-null   object
#  4   Category                1148 non-null   object
#  5   Line Status             0 non-null      float64
#  6   Associated Contract     0 non-null      float64
#  7   Holding status          1148 non-null   object
#  8   Asset Code              1148 non-null   object
#  9   Asset Name              1148 non-null   object
#  10  Tools Code              1148 non-null   object
#  11  Quantity                1148 non-null   float64
#  12  Price                   1069 non-null   float64
#  13  Market Value            1083 non-null   float64
#  14  Accruals                976 non-null    float64
#  15  Currency                1069 non-null   object
#  16  Exchange Rate           1069 non-null   float64
#  17  Future Exposure         65 non-null     float64
#  18  Product Code            65 non-null     float64
#  19  Asset Class Classifier  1148 non-null   object
#  20  Instrument Type         1148 non-null   object
#  21  Instrument Type Name    1148 non-null   object
# dtypes: float64(9), int64(1), object(12)
# memory usage: 197.4+ KB

# %%
portfolio_1_df.describe(include="all")
# Out:
#         Portoflio Code Porfoltio Name Porfolio Currency Holding Date Category  \
# count      1148.000000           1148              1148         1148     1148
# unique             NaN              2                 1            2        4
# top                NaN     Ptf_222222               EUR   19/11/2024     VMOB
# freq               NaN            595              1148          595      976
# mean     168699.018293            NaN               NaN          NaN      NaN
# std       55542.503594            NaN               NaN          NaN      NaN
# min      111111.000000            NaN               NaN          NaN      NaN
# 25%      111111.000000            NaN               NaN          NaN      NaN
# 50%      222222.000000            NaN               NaN          NaN      NaN
# 75%      222222.000000            NaN               NaN          NaN      NaN
# max      222222.000000            NaN               NaN          NaN      NaN
#
#         Line Status  Associated Contract Holding status   Asset Code  \
# count           0.0                  0.0           1148         1148
# unique          NaN                  NaN              1          719
# top             NaN                  NaN            NOR  FutBCO22412
# freq            NaN                  NaN           1148            4
# mean            NaN                  NaN            NaN          NaN
# std             NaN                  NaN            NaN          NaN
# min             NaN                  NaN            NaN          NaN
# 25%             NaN                  NaN            NaN          NaN
# 50%             NaN                  NaN            NaN          NaN
# 75%             NaN                  NaN            NaN          NaN
# max             NaN                  NaN            NaN          NaN
#
#               Asset Name  ...         Price  Market Value      Accruals  \
# count               1148  ...   1069.000000  1.083000e+03    976.000000
# unique               719  ...           NaN           NaN           NaN
# top     Name_FutBCO22412  ...           NaN           NaN           NaN
# freq                   4  ...           NaN           NaN           NaN
# mean                 NaN  ...    575.306516  1.270269e+05    971.135840
# std                  NaN  ...   4700.573197  2.534119e+05   2074.872605
# min                  NaN  ...      0.544321 -2.290549e+05    -63.280000
# 25%                  NaN  ...     59.426440  3.306586e+04      0.000000
# 50%                  NaN  ...     80.444592  8.256125e+04      0.000000
# 75%                  NaN  ...    113.866433  1.477397e+05   1174.660000
# max                  NaN  ...  85834.338680  4.333876e+06  26164.720000
#
#         Currency  Exchange Rate Future Exposure  Product Code  \
# count       1069    1069.000000    6.500000e+01          65.0
# unique        16            NaN             NaN           NaN
# top          EUR            NaN             NaN           NaN
# freq         583            NaN             NaN           NaN
# mean         NaN       0.920105    4.707489e+05           8.0
# std          NaN       0.234841    2.336222e+06           0.0
# min          NaN       0.006153   -7.417704e+06           8.0
# 25%          NaN       0.950029   -5.289111e+05           8.0
# 50%          NaN       1.000000    2.476067e+05           8.0
# 75%          NaN       1.000000    1.008653e+06           8.0
# max          NaN       1.200869    7.391375e+06           8.0
#
#         Asset Class Classifier  Instrument Type Instrument Type Name
# count                     1148             1148                 1148
# unique                       1                1                   12
# top                       yyyy             xxxx      Ordinary shares
# freq                      1148             1148                  557
# mean                       NaN              NaN                  NaN
# std                        NaN              NaN                  NaN
# min                        NaN              NaN                  NaN
# 25%                        NaN              NaN                  NaN
# 50%                        NaN              NaN                  NaN
# 75%                        NaN              NaN                  NaN
# max                        NaN              NaN                  NaN
#
# [11 rows x 22 columns]

# %%
pd.set_option("display.max_columns", None)

# %%
portfolio_1_df.head()
# Out:
#    Portoflio Code Porfoltio Name Porfolio Currency Holding Date Category  \
# 0          111111    Ptf_1111111               EUR   20/11/2024      CAT
# 1          111111    Ptf_1111111               EUR   20/11/2024      CAT
# 2          111111    Ptf_1111111               EUR   20/11/2024      CAT
# 3          111111    Ptf_1111111               EUR   20/11/2024      CAT
# 4          111111    Ptf_1111111               EUR   20/11/2024      CAT
#
#    Line Status  Associated Contract Holding status Asset Code    Asset Name  \
# 0          NaN                  NaN            NOR    frw01G8  Name_frw01G8
# 1          NaN                  NaN            NOR    frw01UH  Name_frw01UH
# 2          NaN                  NaN            NOR    frw01VY  Name_frw01VY
# 3          NaN                  NaN            NOR    frw01WK  Name_frw01WK
# 4          NaN                  NaN            NOR    frw01XE  Name_frw01XE
#
#   Tools Code      Quantity  Price  Market Value  Accruals Currency  \
# 0    frw01G8  7.247088e+04    NaN   -757.671305       NaN      NaN
# 1    frw01UH  1.272192e+06    NaN  11419.880990       NaN      NaN
# 2    frw01VY  5.294401e+04    NaN     90.593711       NaN      NaN
# 3    frw01WK  2.101907e+06    NaN   9206.277708       NaN      NaN
# 4    frw01XE  4.907177e+05    NaN  -2482.073287       NaN      NaN
#
#    Exchange Rate  Future Exposure  Product Code Asset Class Classifier  \
# 0            NaN              NaN           NaN                   yyyy
# 1            NaN              NaN           NaN                   yyyy
# 2            NaN              NaN           NaN                   yyyy
# 3            NaN              NaN           NaN                   yyyy
# 4            NaN              NaN           NaN                   yyyy
#
#   Instrument Type Instrument Type Name
# 0            xxxx     Forward Exchange
# 1            xxxx     Forward Exchange
# 2            xxxx     Forward Exchange
# 3            xxxx     Forward Exchange
# 4            xxxx     Forward Exchange

# %%
portfolio_2_df.head()
# Out:
#    Portoflio Code Porfoltio Name Porfolio Currency Holding Date Category  \
# 0          111111    Ptf_1111111               EUR   21/11/2024      CAT
# 1          111111    Ptf_1111111               EUR   21/11/2024      CAT
# 2          111111    Ptf_1111111               EUR   21/11/2024      CAT
# 3          111111    Ptf_1111111               EUR   21/11/2024      CAT
# 4          111111    Ptf_1111111               EUR   21/11/2024      CAT
#
#    Line Status  Associated Contract Holding status Asset Code    Asset Name  \
# 0          NaN                  NaN            NOR    frw01G8  Name_frw01G8
# 1          NaN                  NaN            NOR    frw01UH  Name_frw01UH
# 2          NaN                  NaN            NOR    frw01VY  Name_frw01VY
# 3          NaN                  NaN            NOR    frw01WK  Name_frw01WK
# 4          NaN                  NaN            NOR    frw01ZR  Name_frw01ZR
#
#   Tools Code      Quantity  Price  Market Value  Accruals Currency  \
# 0    frw01G8  7.247088e+04    NaN   -757.671305       NaN      NaN
# 1    frw01UH  1.272192e+06    NaN  11419.880990       NaN      NaN
# 2    frw01VY  5.294401e+04    NaN     90.593711       NaN      NaN
# 3    frw01WK  2.101907e+06    NaN   9206.277708       NaN      NaN
# 4    frw01ZR  5.972627e+04    NaN   -244.407039       NaN      NaN
#
#    Exchange Rate  Future Exposure  Product Code Asset Class Classifier  \
# 0            NaN              NaN           NaN                   yyyy
# 1            NaN              NaN           NaN                   yyyy
# 2            NaN              NaN           NaN                   yyyy
# 3            NaN              NaN           NaN                   yyyy
# 4            NaN              NaN           NaN                   yyyy
#
#   Instrument Type Instrument Type Name
# 0            xxxx     Forward Exchange
# 1            xxxx     Forward Exchange
# 2            xxxx     Forward Exchange
# 3            xxxx     Forward Exchange
# 4            xxxx     Forward Exchange

# %% [markdown]
# Déterminer s'il y a des lignes en "doublon".

# %%
portfolio_1_df[portfolio_1_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Portoflio Code, Porfoltio Name, Porfolio Currency, Holding Date, Category, Line Status, Associated Contract, Holding status, Asset Code, Asset Name, Tools Code, Quantity, Price, Market Value, Accruals, Currency, Exchange Rate, Future Exposure, Product Code, Asset Class Classifier, Instrument Type, Instrument Type Name]
# Index: []

# %%
portfolio_2_df[portfolio_2_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Portoflio Code, Porfoltio Name, Porfolio Currency, Holding Date, Category, Line Status, Associated Contract, Holding status, Asset Code, Asset Name, Tools Code, Quantity, Price, Market Value, Accruals, Currency, Exchange Rate, Future Exposure, Product Code, Asset Class Classifier, Instrument Type, Instrument Type Name]
# Index: []

# %%
portfolio_1_df[portfolio_1_df.duplicated(subset=[PORTFOLIO_CODE, ASSET_CODE], keep=False)]
# Out:
#      Portoflio Code Porfoltio Name Porfolio Currency Holding Date Category  \
# 47           111111    Ptf_1111111               EUR   20/11/2024     FUTU
# 62           111111    Ptf_1111111               EUR   20/11/2024     FUTU
# 69           111111    Ptf_1111111               EUR   20/11/2024     FUTU
# 70           111111    Ptf_1111111               EUR   20/11/2024     FUTU
# 274          111111    Ptf_1111111               EUR   20/11/2024     VMOB
# 275          111111    Ptf_1111111               EUR   20/11/2024     VMOB
# 371          111111    Ptf_1111111               EUR   20/11/2024     VMOB
# 372          111111    Ptf_1111111               EUR   20/11/2024     VMOB
# 597          222222     Ptf_222222               EUR   19/11/2024     FUTU
# 602          222222     Ptf_222222               EUR   19/11/2024     FUTU
# 612          222222     Ptf_222222               EUR   19/11/2024     FUTU
# 620          222222     Ptf_222222               EUR   19/11/2024     FUTU
# 621          222222     Ptf_222222               EUR   19/11/2024     FUTU
# 622          222222     Ptf_222222               EUR   19/11/2024     FUTU
# 847          222222     Ptf_222222               EUR   19/11/2024     VMOB
# 848          222222     Ptf_222222               EUR   19/11/2024     VMOB
# 964          222222     Ptf_222222               EUR   19/11/2024     VMOB
# 965          222222     Ptf_222222               EUR   19/11/2024     VMOB
#
#      Line Status  Associated Contract Holding status    Asset Code  \
# 47           NaN                  NaN            NOR   FutUCO22412
# 62           NaN                  NaN            NOR   FutBCO22412
# 69           NaN                  NaN            NOR   FutBCO22412
# 70           NaN                  NaN            NOR   FutUCO22412
# 274          NaN                  NaN            NOR  ISINS7620S9Y
# 275          NaN                  NaN            NOR  ISINS7620S9Y
# 371          NaN                  NaN            NOR  ISIN01Q91500
# 372          NaN                  NaN            NOR  ISIN01Q91500
# 597          NaN                  NaN            NOR   FutBCO22412
# 602          NaN                  NaN            NOR   FutPIN22412
# 612          NaN                  NaN            NOR   FutPIN22412
# 620          NaN                  NaN            NOR   FutUCO22412
# 621          NaN                  NaN            NOR   FutBCO22412
# 622          NaN                  NaN            NOR   FutUCO22412
# 847          NaN                  NaN            NOR  ISINS7620S9Y
# 848          NaN                  NaN            NOR  ISINS7620S9Y
# 964          NaN                  NaN            NOR  ISIN01Q91500
# 965          NaN                  NaN            NOR  ISIN01Q91500
#
#             Asset Name    Tools Code     Quantity        Price   Market Value  \
# 47    Name_FutUCO22412   FutUCO22412    31.609809    80.745280            NaN
# 62    Name_FutBCO22412   FutBCO22412    -2.370736   112.696870            NaN
# 69    Name_FutBCO22412   FutBCO22412    11.063433   105.782224            NaN
# 70    Name_FutUCO22412   FutUCO22412    42.673242    84.417945            NaN
# 274  Name_ISINS7620S9Y  ISINS7620S9Y   303.454162   340.437638  130728.052900
# 275  Name_ISINS7620S9Y  ISINS7620S9Y  1296.792395   359.616889  560641.568500
# 371  Name_ISIN01Q91500  ISIN01Q91500  2245.876896     9.615704   27327.833230
# 372  Name_ISIN01Q91500  ISIN01Q91500  6513.991291     9.617284   79275.274020
# 597   Name_FutBCO22412   FutBCO22412    -1.580490   112.696870            NaN
# 602   Name_FutPIN22412   FutPIN22412     2.370736  2121.808397            NaN
# 612   Name_FutPIN22412   FutPIN22412     0.790245  6596.176794            NaN
# 620   Name_FutUCO22412   FutUCO22412    37.931770    80.745280            NaN
# 621   Name_FutBCO22412   FutBCO22412    -3.951226   105.782224            NaN
# 622   Name_FutUCO22412   FutUCO22412   -16.595149    84.417945            NaN
# 847  Name_ISINS7620S9Y  ISINS7620S9Y    74.283050   340.437638   32001.137950
# 848  Name_ISINS7620S9Y  ISINS7620S9Y   381.688438   359.616889  165015.156900
# 964  Name_ISIN01Q91500  ISIN01Q91500   575.298515     9.615704    7000.229171
# 965  Name_ISIN01Q91500  ISIN01Q91500  1577.329445     9.617284   19196.099350
#
#      Accruals Currency  Exchange Rate  Future Exposure  Product Code  \
# 47        NaN      USD       0.950029     6.159479e+06           8.0
# 62        NaN      JPY       0.006153    -2.080174e+06           8.0
# 69        NaN      EUR       1.000000     1.480951e+06           8.0
# 70        NaN      EUR       1.000000     4.558569e+06           8.0
# 274       0.0      EUR       1.000000              NaN           NaN
# 275       0.0      USD       0.950029              NaN           NaN
# 371       0.0      EUR       1.000000              NaN           NaN
# 372       0.0      EUR       1.000000              NaN           NaN
# 597       NaN      JPY       0.006153    -1.386782e+06           8.0
# 602       NaN      JPY       0.006153     3.916462e+05           8.0
# 612       NaN      AUD       0.619540     1.021649e+05           8.0
# 620       NaN      USD       0.950029     7.391375e+06           8.0
# 621       NaN      EUR       1.000000    -5.289111e+05           8.0
# 622       NaN      EUR       1.000000    -1.772777e+06           8.0
# 847       0.0      EUR       1.000000              NaN           NaN
# 848       0.0      USD       0.950029              NaN           NaN
# 964       0.0      EUR       1.000000              NaN           NaN
# 965       0.0      EUR       1.000000              NaN           NaN
#
#     Asset Class Classifier Instrument Type Instrument Type Name
# 47                    yyyy            xxxx         Bond futures
# 62                    yyyy            xxxx         Bond futures
# 69                    yyyy            xxxx         Bond futures
# 70                    yyyy            xxxx         Bond futures
# 274                   yyyy            xxxx      Ordinary shares
# 275                   yyyy            xxxx      Ordinary shares
# 371                   yyyy            xxxx      Ordinary shares
# 372                   yyyy            xxxx      Ordinary shares
# 597                   yyyy            xxxx         Bond futures
# 602                   yyyy            xxxx        Index futures
# 612                   yyyy            xxxx        Index futures
# 620                   yyyy            xxxx         Bond futures
# 621                   yyyy            xxxx         Bond futures
# 622                   yyyy            xxxx         Bond futures
# 847                   yyyy            xxxx      Ordinary shares
# 848                   yyyy            xxxx      Ordinary shares
# 964                   yyyy            xxxx      Ordinary shares
# 965                   yyyy            xxxx      Ordinary shares

# %% [markdown]
# Agréger les lignes multiples associées à un même couple (portfolio, asset), en utilisant une fonction d'agrégation pertinente.

# %%
aggregated_portfolio_1_df = portfolio_1_df[
    [PORTFOLIO_CODE, ASSET_CODE, QUANTITY]
].groupby(
    [PORTFOLIO_CODE, ASSET_CODE],
    as_index=False,
).sum()  # alternative : utiliser agg
aggregated_portfolio_1_df
# Out:
#       Portoflio Code Asset Code      Quantity
# 0             111111    CashAUD  9.517818e+04
# 1             111111    CashCAD  1.487054e+04
# 2             111111    CashCHF  3.419562e+04
# 3             111111    CashDKK  8.700876e+04
# 4             111111    CashEUR  1.810676e+05
# ...              ...        ...           ...
# 1134          222222    frw06GY  2.256224e+04
# 1135          222222    frw079D  9.939006e+06
# 1136          222222    frw07BR  9.645461e+05
# 1137          222222    frw07KD  7.421405e+05
# 1138          222222    frw0AJH  2.292223e+06
#
# [1139 rows x 3 columns]

# %%
aggregated_portfolio_2_df = portfolio_2_df[
    [PORTFOLIO_CODE, ASSET_CODE, QUANTITY]
].groupby(
    [PORTFOLIO_CODE, ASSET_CODE],
    as_index=False,
).sum()  # alternative : utiliser agg
aggregated_portfolio_2_df
# Out:
#       Portoflio Code Asset Code      Quantity
# 0             111111    CashAUD  9.517818e+04
# 1             111111    CashCAD  1.487054e+04
# 2             111111    CashCHF  3.419562e+04
# 3             111111    CashDKK  8.700876e+04
# 4             111111    CashEUR  1.810676e+05
# ...              ...        ...           ...
# 1134          222222    frw06GY  2.256224e+04
# 1135          222222    frw079D  9.939006e+06
# 1136          222222    frw07BR  9.645461e+05
# 1137          222222    frw07KD  7.421405e+05
# 1138          222222    frw0AJH  2.292223e+06
#
# [1139 rows x 3 columns]

# %% [markdown]
# Ecrire un petit script permettant de calculer les variations de chaque asset de chaque portfolio, dès lors qu'il y a eu une variation non nulle. Stocker les résultats dans un dataframe.

# %%
merged_quantity_df = aggregated_portfolio_1_df.merge(
    aggregated_portfolio_2_df,
    how="outer",
    on=[PORTFOLIO_CODE, ASSET_CODE],
    suffixes=["_before", "_after"],
).fillna(0)

# %%
merged_quantity_df["variation"] = merged_quantity_df[f"{QUANTITY}_after"] - merged_quantity_df[f"{QUANTITY}_before"]

# %%
merged_quantity_df
# Out:
#       Portoflio Code Asset Code  Quantity_before  Quantity_after  variation
# 0             111111    CashAUD     9.517818e+04    9.517818e+04        0.0
# 1             111111    CashCAD     1.487054e+04    1.487054e+04        0.0
# 2             111111    CashCHF     3.419562e+04    3.419562e+04        0.0
# 3             111111    CashDKK     8.700876e+04    8.700876e+04        0.0
# 4             111111    CashEUR     1.810676e+05    1.810676e+05        0.0
# ...              ...        ...              ...             ...        ...
# 1166          222222    frw06GY     2.256224e+04    2.256224e+04        0.0
# 1167          222222    frw079D     9.939006e+06    9.939006e+06        0.0
# 1168          222222    frw07BR     9.645461e+05    9.645461e+05        0.0
# 1169          222222    frw07KD     7.421405e+05    7.421405e+05        0.0
# 1170          222222    frw0AJH     2.292223e+06    2.292223e+06        0.0
#
# [1171 rows x 5 columns]

# %%
non_zero_variation_df = merged_quantity_df[merged_quantity_df["variation"] != 0]

# %%
non_zero_variation_df
# Out:
#       Portoflio Code    Asset Code  Quantity_before  Quantity_after  \
# 45            111111  ISIN00018578         0.000000     6875.133354
# 55            111111  ISIN00069035         0.000000     7033.182396
# 61            111111  ISIN00096472         0.000000    22601.013090
# 66            111111  ISIN01759635     79024.521310        0.000000
# 84            111111  ISIN07750454    102731.877700        0.000000
# ...              ...           ...              ...             ...
# 1095          222222  ISINLCK11400         0.000000    79024.521310
# 1122          222222       TresDKK     14233.398920        0.000000
# 1123          222222       TresEUR     90776.645090        0.000000
# 1124          222222       TresGBP      3951.226065        0.000000
# 1125          222222       TresHKD     14785.314080        0.000000
#
#           variation
# 45      6875.133354
# 55      7033.182396
# 61     22601.013090
# 66    -79024.521310
# 84   -102731.877700
# ...             ...
# 1095   79024.521310
# 1122  -14233.398920
# 1123  -90776.645090
# 1124   -3951.226065
# 1125  -14785.314080
#
# [63 rows x 5 columns]

# %% [markdown]
# Visualiser la distribution des variations non nulles.

# %%
# plt.figure()
plt.hist(x=non_zero_variation_df["variation"])
plt.title("Distribution des variations des compositions des portefeuilles")
plt.xlabel("Variation")
plt.ylabel("Nombre d'occurrences")
plt.show()

# %% [markdown]
# Visualiser la composition du portefeuille 111111 (choisir un des deux jours).

# %%
pie_mask = (
    (aggregated_portfolio_1_df[PORTFOLIO_CODE] == 111111)
    &
    (aggregated_portfolio_1_df[QUANTITY] > 0)
)

pie_df = aggregated_portfolio_1_df[pie_mask].sort_values(QUANTITY, ascending=False)

# %%
plt.figure()
plt.pie(
    pie_df[QUANTITY],
    labels=pie_df[ASSET_CODE],
)
plt.title("Composition du portefeuille 111111")
plt.show()

# %% [markdown]
# Regrouper les assets représentant moins de 2% du total dans une catégorie "others".

# %%
asset_quantity_total = pie_df[QUANTITY].sum()
threshold = 0.02 * asset_quantity_total
other_mask = pie_df[QUANTITY] < threshold

major_assets = pie_df[~other_mask]  # ~ : négation
minor_assets = pie_df[other_mask]

label_list = major_assets[ASSET_CODE].tolist()
value_list = major_assets[QUANTITY].tolist()
if not minor_assets.empty:
    label_list.append("Others")
    value_list.append(minor_assets[QUANTITY].sum())

# %%
plt.figure()
plt.pie(
    value_list,
    labels=label_list,
    autopct="%1.1f%%",
    wedgeprops={
        "linewidth": 1.2,
        "edgecolor": "white",
    }
)
plt.title("Composition du portefeuille 111111")
plt.tight_layout()
plt.show()

# %% [markdown]
# Exporter le dataframe des variations au format CSV.

# %%
# Votre code ici
